# %% [markdown]
# # 3. Simulation Analysis
#
# Analyzing results from larger Monte Carlo simulation runs, including convergence and variance.

# %%
# Import libraries
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns

# Load simulation results (adjust path)
# try:
#     sim_results = pd.read_csv('../data/simulation_results/your_sim_output.csv')
#     print("Simulation results loaded.")
#     print(sim_results.describe())
# except FileNotFoundError:
#     print("Simulation results file not found.")

# %% [markdown]
# ## Convergence Analysis
#
# Plot metrics (e.g., RTP) over the number of spins to check for convergence.

# %%
# Assuming results contain cumulative metrics or run identifiers
# plt.figure(figsize=(10, 6))
# plt.plot(sim_results['spin_number'], sim_results['cumulative_rtp'])
# plt.title('RTP Convergence over Spins')
# plt.xlabel('Number of Spins')
# plt.ylabel('Cumulative RTP')
# plt.grid(True)
# plt.show()

# %% [markdown]
# ## Distribution Analysis
#
# Analyze the distribution of payouts.

# %%
# plt.figure(figsize=(10, 6))
# sns.histplot(sim_results['payout_multiplier'], bins=50, kde=True)
# plt.title('Distribution of Payout Multipliers')
# plt.xlabel('Payout Multiplier (x Bet)')
# plt.ylabel('Frequency')
# plt.yscale('log') # Often useful for skewed payout distributions
# plt.grid(True)
# plt.show()
