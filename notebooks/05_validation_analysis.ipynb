# %% [markdown]
# # 5. Validation Analysis
#
# Comparing model predictions (from simulation/optimization) against actual observed data (e.g., anonymized game logs).

# %%
# Import libraries
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt

# Load processed actual data (adjust path)
# try:
#     actual_data = pd.read_csv('../data/processed/processed_game_logs.csv')
#     print("Actual data loaded.")
# except FileNotFoundError:
#     print("Processed actual data file not found.")

# Load model predictions (e.g., from simulation results for a specific design)
# try:
#     predicted_data = pd.read_csv('../data/simulation_results/predicted_metrics.csv')
#     print("Predicted data loaded.")
# except FileNotFoundError:
#     print("Predicted data file not found.")

# %% [markdown]
# ## Comparison: RTP Trajectory
#
# Compare the evolution of RTP over time/spins between simulation and actual play.

# %%
# Calculate cumulative RTP from actual data
# actual_data['cumulative_rtp'] = actual_data['payout'].cumsum() / actual_data['bet'].cumsum()

# Plot comparison
# plt.figure(figsize=(12, 7))
# plt.plot(actual_data['spin_index'], actual_data['cumulative_rtp'], label='Actual Data')
# plt.plot(predicted_data['spin_number'], predicted_data['cumulative_rtp'], label='Model Prediction', linestyle='--')
# plt.title('RTP Trajectory: Actual vs. Predicted')
# plt.xlabel('Spin Number')
# plt.ylabel('Cumulative RTP')
# plt.legend()
# plt.grid(True)
# plt.show()

# %% [markdown]
# ## Comparison: Payout Distribution
#
# Compare the distribution of payout multipliers.

# %%
# plt.figure(figsize=(12, 7))
# sns.histplot(actual_data['payout'] / actual_data['bet'], bins=50, kde=False, label='Actual', stat='density', alpha=0.6)
# sns.histplot(predicted_data['payout_multiplier'], bins=50, kde=False, label='Predicted', stat='density', alpha=0.6)
# plt.title('Payout Multiplier Distribution: Actual vs. Predicted')
# plt.xlabel('Payout Multiplier')
# plt.ylabel('Density')
# plt.yscale('log')
# plt.legend()
# plt.grid(True)
# plt.show()

# %% [markdown]
# ## Other Metrics
#
# *   Compare hit frequency.
# *   Compare variance (if calculable from actual data).
# *   Compare player session length / churn (if available).
